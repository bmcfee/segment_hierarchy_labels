# %%
import numpy as np
import jams
import scipy
import jams.display
import matplotlib.pyplot as plt
# %matplotlib nbagg
import matplotlib.style as ms
ms.use('seaborn-muted')
ms.use('seaborn-darkgrid')

# %%
idx = 278

# %%
j_ref = jams.load('../data/SPAM/SALAMI_{}.jams'.format(idx), validate=False)

# %%
j_est = jams.load('../data/estimations/SPAM/SALAMI_{}.jams'.format(idx), validate=False)

# %%
print(j_est.annotations[0].sandbox)
# Out:
# {
#   "labels_id": "scluster",
#   "num_types": null,
#   "median": false,
#   "timestamp": "2016/09/20 05:39:25",
#   "feature": "pcp",
#   "verbose": false,
#   "num_layers": 10,
#   "hier": true,
#   "framesync": false,
#   "annot_beats": false,
#   "boundaries_id": "scluster",
#   "start_layer": 1
# }

# %%
j_est.annotations[0].data
# Out:
#               time        duration                       value confidence
# 0         00:00:00 00:00:00.975238  {'label': 'B', 'level': 0}       None
# 1  00:00:00.975238 00:03:48.902313  {'label': 'A', 'level': 0}       None
# 2  00:03:49.877551 00:00:10.187755  {'label': 'B', 'level': 0}       None
# 3         00:00:00 00:00:00.975238  {'label': 'C', 'level': 1}       None
# 4  00:00:00.975238 00:01:37.941769  {'label': 'B', 'level': 1}       None
# 5  00:01:38.917007 00:02:10.960544  {'label': 'A', 'level': 1}       None
# 6  00:03:49.877551 00:00:10.187755  {'label': 'C', 'level': 1}       None
# 7         00:00:00 00:00:00.975238  {'label': 'D', 'level': 2}       None
# 8  00:00:00.975238 00:00:36.269569  {'label': 'C', 'level': 2}       None
# 9  00:00:37.244807 00:01:01.672200  {'label': 'B', 'level': 2}       None
# 10 00:01:38.917007 00:02:10.960544  {'label': 'A', 'level': 2}       None
# 11 00:03:49.877551 00:00:10.187755  {'label': 'D', 'level': 2}       None
# ...

# %%
j_est.file_metadata.duration
# Out:
# 240.065306122449

# %%
jams.display.display_multi(j_ref.annotations['multi'], meta=False)

plt.figure()
jams.display.display(j_est.annotations[0], meta=False)
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
plt.close('all')
